# %%
using Polynomials

# %%
coeffs = [0.0919013402/2,
 0.0,
 -0.118938347,
 -0.0,
 0.0983220421,
 0.0,
 -0.1033117852,
 0.0,
 0.123447107,
 -0.0,
 -0.0825058698,
 -0.0,
 0.1079723552,
 -0.0,
 -0.1389198904,
 -0.0,
 0.1055656249,
 -0.0,
 -0.0515506084,
 -0.0,
 0.0177786432,
 -0.0,
 -0.0046150454,
 0.0,
 0.0009418619,
 -0.0,
 -0.0001559367,
 -0.0,
 2.14445e-05,
 -0.0,
 -2.4952e-06,
 0.0,
 2.493e-07,
 -0.0,
 -2.17e-08,
 0.0,
 1.7e-09,
 -0.0,
 -1e-10]
# Out:
# 39-element Vector{Float64}:
#   0.0459506701
#   0.0
#  -0.118938347
#  -0.0
#   0.0983220421
#   0.0
#  -0.1033117852
#   0.0
#   0.123447107
#  -0.0
#  -0.0825058698
#  -0.0
#   0.1079723552
#   ⋮
#  -0.0
#   2.14445e-5
#  -0.0
#  -2.4952e-6
#   0.0
#   2.493e-7
#  -0.0
#  -2.17e-8
#   0.0
#   1.7e-9
#  -0.0
#  -1.0e-10

# %%
T = ChebyshevT(coeffs)
T(0.01)
# Out:
# 0.9940887484504299
